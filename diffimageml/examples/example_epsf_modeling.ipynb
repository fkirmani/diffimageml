# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from matplotlib import pyplot as plt
from matplotlib import cm

import numpy as np
from astropy.io import fits
from astropy.table import Table, Column
from astropy.wcs import utils as wcsutils
from astropy import units
from astropy.coordinates import SkyCoord

# %%
import os

# %%
from diffimageml import diffimageml

# %% [markdown]
# ## Load in one of the example images from the test_data directory

# %%
_SEARCHIM1_ = '../test_data/sky_image_1.fits.fz'
assert(os.path.isfile(_SEARCHIM1_))
searchim = diffimageml.FitsImage(_SEARCHIM1_)

# %% [markdown]
# ## Fetch a catalog of stars in the image from the Gaia db

# %%
# TODO : show gaia star fetching
searchim.fetch_gaia_sources()
# Out:
# Gaia catalog ../test_data/sky_image_1_GaiaCat.ecsv exists.
# Reading without fetching.

# %%
searchim.show_gaia_sources(magmin=12, magmax=18)

# %% [markdown]
# ## Do Photometry of the Gaia Stars

# %%
searchim.do_stellar_photometry(searchim.gaia_source_table)
# TODO : show photometry of the gaia stars
# Out:
# /Users/rodney/src/diffimageml/diffimageml/fakeplanting.py:543: RuntimeWarning: invalid value encountered in log10
#   phot['mag'] = -2.5 * np.log10( phot['aper_sum_bkgsub'] )

# %%
searchim.stellar_phot_table
# Out:
# <QTable length=490>
#   id       xcenter       ...  aper_sum_bkgsub           mag
#              pix         ...
# int64      float64       ...      float64             float64
# ----- ------------------ ... ------------------ -------------------
#     1 2000.1174599768954 ... 29080.702261593397 -11.159012224918353
#     2 2147.9167028502843 ... 5317.6178663367755  -9.314292812319547
#     3 2022.6537577426254 ... 2639.2898857478285  -8.553717733665456
#     4 2092.3268097324853 ... 62891.733628293325 -11.996483915857159
#     5 2056.0133611942483 ... 3950.8734641995106   -8.99173280156383
#     6 1964.8116810576942 ...  55717.26225510458   -11.8649744215374
#     7 2256.2568375243904 ...  85993.18021929427 -12.336160026057488
#     8  2253.908258227181 ...  6782.692716952763  -9.578505355593895
#     9 1898.2483264391988 ...  22205.73338976875 -10.866162803025523
#   ...                ... ...                ...                 ...
#   481 448.39436060356934 ... 474.41304520874615  -6.690391556414755
#   482 3893.4886280822893 ... 12934.279833007924 -10.279355631673202
#   483 111.93347335910948 ...   5076.74577557703  -9.263963540268243
#   484  79.54107770534029 ...  4393.934467219777  -9.107133938506593
#   485 211.57290745106752 ... 16714.019301939115 -10.557702248425082
#   486 301.51354755002103 ... 4089.0399034811126   -9.02905337174968
#   487 3867.9223824398223 ...  73638.88287359053  -12.16776797872459
#   488 158.73172477110143 ... 17817.842696580716 -10.627137801204077
#   489 129.41601888472587 ... 7836.1395921657095  -9.735255409669465
#   490 3994.8530966345656 ... -66989.06347890291                 nan

# %% [markdown]
# ## Measure the zero point for this image from the Gaia stars

# %%
searchim.measure_zeropoint(showplot=True)

# %% [markdown]
# ## Build an ePSF Model from the Gaia stars that are not saturated

# %%
# TODO : show the ePSF model building
